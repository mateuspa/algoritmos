# %%
#Prática Aula 1 - Jupyter Notebook

# Inicialização das Variáveis
#nome = str(input("Digite o nome do aluno: "))
valor1 = float(input("Digite a valor 1: "))

# cálculos
quadrado = valor1**2
cubo = valor1**3

# interface
print(f"")
print(f"Quadrado: {quadrado}")
print(f"Cubo: {cubo}")
# Out:
# Quadrado: 144.0
# Cubo: 1728.0
